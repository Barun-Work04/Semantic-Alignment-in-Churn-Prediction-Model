# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
import pickle

df = pd.read_csv('../data/gaming_churn.csv')

# Create binary churn target
df['Churn'] = df['EngagementLevel'].apply(lambda x: 0 if x == 'High' else 1)

# Drop original target (we replaced it)
df.drop(columns=['EngagementLevel', 'PlayerID'], inplace=True, errors='ignore')

df.head()
# Out:
#    Age  Gender Location GameGenre  PlayTimeHours  InGamePurchases  \
# 0   43    Male    Other  Strategy      16.271119                0
# 1   29  Female      USA  Strategy       5.525961                0
# 2   22  Female      USA    Sports       8.223755                0
# 3   35    Male      USA    Action       5.265351                1
# 4   33    Male   Europe    Action      15.531945                0
#
#   GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# 0         Medium                6                        108           79
# 1         Medium                5                        144           11
# 2           Easy               16                        142           35
# 3           Easy                9                         85           57
# 4         Medium                2                        131           95
#
#    AchievementsUnlocked  Churn
# 0                    25      1
# 1                    10      1
# ...

# %%
categorical_cols = df.select_dtypes(include='object').columns.tolist()
print("Categorical columns:", categorical_cols)

le = LabelEncoder()
for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

df.head()
# Out:
# Categorical columns: ['Gender', 'Location', 'GameGenre', 'GameDifficulty']
#    Age  Gender  Location  GameGenre  PlayTimeHours  InGamePurchases  \
# 0   43       1         2          4      16.271119                0
# 1   29       0         3          4       5.525961                0
# 2   22       0         3          3       8.223755                0
# 3   35       1         3          0       5.265351                1
# 4   33       1         1          0      15.531945                0
#
#    GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# 0               2                6                        108           79
# 1               2                5                        144           11
# 2               0               16                        142           35
# 3               0                9                         85           57
# 4               2                2                        131           95
#
# ...

# %%
X = df.drop(columns=['Churn'])
y = df['Churn']

print("Features shape:", X.shape)
print("Churn distribution:\n", y.value_counts())
# Out:
# Features shape: (40034, 11)
# Churn distribution:
#  Churn
# 1    29698
# 0    10336
# Name: count, dtype: int64

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# Save scaler for deployment later
with open('../models/scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

print("Scaling done. Saved scaler.pkl")
# Out:
# Scaling done. Saved scaler.pkl

# %%
X_scaled.to_csv('../data/X_processed.csv', index=False)
y.to_csv('../data/y_processed.csv', index=False)
print("Saved processed data.")
# Out:
# Saved processed data.
